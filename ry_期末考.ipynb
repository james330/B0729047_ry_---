# %% [markdown]
# <a href="https://colab.research.google.com/github/james330/B0729047_ry_---/blob/main/ry_%E6%9C%9F%E6%9C%AB%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy      as np
import scipy.special  as sp
import scipy.stats   as st
import pandas      as pd


n= 10 
μ= 5
σ= 2

# %%
#(1)
(1/n)*n*μ
# Out:
# 5.0

# %%
#(2)
σ**2
# Out:
# 4

# %%
#(3)
import math
a=math.sqrt(10)
(5-μ)/(math.sqrt(4)/math.sqrt(10))
# Out:
# 0.0

# %%
#(4)
#Var(X)=σ^2/n
(σ**2)/10
# Out:
# 0.4

# %%
#(5)
(2*(σ**2)*(σ**2))/(n-1)
# Out:
# 3.5555555555555554

# %%
#(6)
(0.4-μ)/(math.sqrt(3.5555555555555554)/math.sqrt(10))
# Out:
# -7.714434522374275

# %%
#(7)
#math.exp((-1/2)*((x-μ)/σ)**2)

# %%
#(8)
#math.exp((-1/2)*((q-μ)/σ)**2)

# %%
#(9)
#math.exp((-1/2)*((t-μ)/σ)**2)

# %%
#(10)
math.exp((-1/2)*((4-μ)/σ)**2)
# Out:
# 0.8824969025845955

# %%
#(11)
math.exp((-1/2)*((3-4)/σ)**2)
# Out:
# 0.8824969025845955

# %%
#(12)
math.exp((-1/2)*((-1-0)/σ)**2)
# Out:
# 0.8824969025845955

# %%
#(13)
e13=1.96*(σ/math.sqrt(10))
5-e13
# Out:
# 3.7603871572139953

# %%
#(13_2)
5+e13
# Out:
# 6.239612842786005

# %%
#(14)
e14=1.96*(σ/math.sqrt(10))
4-e14
# Out:
# 2.7603871572139953

# %%
#(14_2)
4+e14
# Out:
# 5.239612842786005

# %%
#(15)
e15=1.96*(σ/math.sqrt(10))
0-e15
# Out:
# -1.2396128427860047

# %%
#(15_2)
0+e15
# Out:
# 1.2396128427860047

# %%
#(16)
arr=[147.6 ,185.9 ,154.0 ,147.2 ,168.6 ,146.8 ,162.6 ,164.1 ,152.2 ,171.8]
np.mean(arr)
# Out:
# 160.07999999999998

# %%
#(17)
np.std(arr)
# Out:
# 12.23190909057127

# %%
#(18)
a=np.mean(arr)-(1.96)*(np.std(arr)/math.sqrt(10))
b=np.mean(arr)+(1.96)*(np.std(arr)/math.sqrt(10))
a
# Out:
# 152.49858419976846

# %%
#(18_2)
b
# Out:
# 167.6614158002315

# %%
#(19)
arr2=[147.6 ,185.9 ,154.0 ,147.2 ,168.6 ,146.8 ,162.6 ,164.1 ,152.2 ,171.8 ,151.4	,152.0	,177.1	,155.1	,159.8	,188.0	,163.7	,178.6	,144.0	,161.8]
a2=np.mean(arr2)-(1.96)*(np.std(arr2)/math.sqrt(10))
b2=np.mean(arr2)+(1.96)*(np.std(arr2)/math.sqrt(10))
a2
# Out:
# 153.65174709405758

# %%
#(19_2)
b2
# Out:
# 169.57825290594238

# %%
#(20)
#10人的
b-a
# Out:
# 15.16283160046305

# %%
#(20_2)
#20人的
b2-a2
# Out:
# 15.926505811884795

# %%
#10人的信心區間寬度較小
